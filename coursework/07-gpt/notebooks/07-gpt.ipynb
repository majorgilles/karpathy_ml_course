# %% [markdown]
# # Lesson 07 — Let's build GPT: from scratch, in code, spelled out.
#
# - **GitHub issue:** [#7](https://github.com/majorgilles/karpathy_ml_course/issues/7)
# - **Video:** https://www.youtube.com/watch?v=kCc8FmEb1nY
# - **Lesson notes:** [lessons/07-gpt-from-scratch.md](../../../lessons/07-gpt-from-scratch.md)
# - **Transcript:** [video_transcripts/07-gpt-from-scratch.md](../../../video_transcripts/07-gpt-from-scratch.md)
#
# Use this notebook for exploratory follow-along work. Move reusable code to `../src/`, lightweight checks to `../tests/`, and representative outputs to `../artifacts/`.
